# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

#sample data
x=np.array([5,15,25,35,45,55]).reshape((-1,1))
y=np.array([5,20,14,32,22,38])

#create a linear regression modle
modle = LinearRegression()

#fit the model to the data
modle.fit(x,y)

# print the slop and intercept
print("slope:",modle.coef_[0])
print("intercept:",modle.intercept_)

# make prediction
x_new = np.array([6]).reshape((-1,1))
print("prediction y for x=6:",'y_Pred'[0])

#plot the data and the result
plt.scatter(x,y,color="blue",label="data point")
plt.plot(x,modle.predict(x),color="red",label="regression line")
plt.scatter(x_new,y_pred,clor="green",lable="prediction value")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# slope: 0.54
# intercept: 5.633333333333329
# prediction y for x=6: y
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-4186636020.py in <cell line: 0>()
#      24 plt.scatter(x,y,color="blue",label="data point")
#      25 plt.plot(x,modle.predict(x),color="red",label="regression line")
# ---> 26 plt.scatter(x_new,y_pred,clor="green",lable="prediction value")
#      27 plt.xlabel("x")
#      28 plt.ylabel("y")
#
# NameError: name 'y_pred' is not defined
